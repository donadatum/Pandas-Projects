# %% [markdown]
# ## Collecting Twitter Data
#
# ### Twitter has an API to enable collection of streaming Twitter data.  The API documentation is extensive.  Keys can be obtained by logging in to apps.twitter.com.
#
# #### The script below uses tweepy to collect and print 200 tweets with the #Delta handle.  Alternatively tweets can be saved to a JSON file.

# %%
import tweepy
import pprint
import sys
from tweepy import OAuthHandler

consumer_key = 'XXXXXXXXXXXX'
consumer_secret = 'XXXXXXXXXXXX'
access_token = 'XXXXXXXXXXXX'
access_secret = 'XXXXXXXXXXXXXXX'

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)
deltaTweet = tweepy.Cursor(api.search, q='#Delta').items(200)

for tweet in deltaTweet:
   print (tweet.created_at, tweet.text)
   #results = tweet.created_at + "," +  tweet_text
   with open('delta2.txt','a') as f:
       f.write(tweet.text)
# Out:
# 2018-01-17 19:24:38 Delta continues Boston expansion with more flights to top destinations    https://t.co/6stWB7TbZL   #news #travel… https://t.co/6OWPRdpMxC
# 2018-01-17 19:24:32 Have been delayed 2+ hours &amp; now boarded, de-planed &amp; boarded again with no explanation for what’s wrong. Missed a… https://t.co/j2K6quUXYB
# 2018-01-17 19:21:54 Delta’s Seattle growth continues for sixth straight year    https://t.co/BOnkvXJsST   #news #travel #avgeek… https://t.co/tQYtfnpeKV
# 2018-01-17 19:16:51 Be safe, but not clean... #DeltaLife #DeltaMedallion #Delta 😏 https://t.co/p1iofEwaZj
# 2018-01-17 19:16:43 DM sent. Now let’s see if they make it right.... and it had nothing to do with the weather in atl that almost made… https://t.co/d4Z3mib3uO
# 2018-01-17 19:14:20 Soaring with the eagles near MCI #DELTA #MCI https://t.co/p9LmrTIm0o
# ...
